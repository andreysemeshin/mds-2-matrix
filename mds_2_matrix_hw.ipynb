# %% [markdown]
# Домашнее задание
#
# Уровень 0:
# Создайте матрицу 3 на 3, заполненную числами от 1 до 9
# Прибавьте к ней матрицу с единицами на диагонале
# Умножьте полученную матрицу на вектор (1, 2, 3)
# Посчитайте обратную матрицу к полученной матрице

# %%
import numpy as np

# %%
# Создайте матрицу 3 на 3, заполненную числами от 1 до 9
matrix_1 = np.array(np.random.randint(9, size=(3,3)))
matrix_1
# Out:
# array([[1, 3, 4],
#        [5, 4, 1],
#        [0, 4, 1]])

# %%
# Прибавьте к ней матрицу с единицами на диагонале
matrix_2 = np.eye(3)
matrix_2
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
matrix_1 = matrix_1 + matrix_2
matrix_1
# Out:
# array([[2., 3., 4.],
#        [5., 5., 1.],
#        [0., 4., 2.]])

# %%
# Посчитайте обратную матрицу к полученной матрице
matrix_1 = np.linalg.inv(matrix_1)
matrix_1
# Out:
# array([[ 0.09677419,  0.16129032, -0.27419355],
#        [-0.16129032,  0.06451613,  0.29032258],
#        [ 0.32258065, -0.12903226, -0.08064516]])

# %%
# вектор (1, 2, 3) 
vector = np.array([1,2,3])
vector
# Out:
# array([1, 2, 3])

# %%
# Умножьте полученную матрицу на вектор (1, 2, 3) 
matrix_1 = matrix_1 @ vector
print('Result: ', matrix_1)
# Out:
# Result:  [-0.40322581  0.83870968 -0.17741935]

# %% [markdown]
# Уровень 1:
# Дан объект в 2d пространстве:
# import numpy as np
# import matplotlib.pyplot as plt
#
# A = [
# [-100, -100, 1],
# [-100, 100, 1],
# [100, 100, 1],
# [0, 0, 1],
# [100, -100, 1],
# [-100, -100, 1]
# ]
# A = np.array(A)
# x = A[:,0]
# y = A[:,1]
# plt.plot(x, y)
# plt.ylim([-200, 200])
# plt.xlim([-200, 200])
#
# При помощи матричных операций выполните:
# Уменьшить объект в два раза.
# Повернуть на 130 градусов.
# Отразить объект относительно прямой y=x
# Выполнить смещение объекта и масштабирование (применить 2 матрицы трансформаций).
# Смещение на (200, 300) и масштабирование на (0.5, 1,2)

# %%
import numpy as np 
import matplotlib.pyplot as plt

A = [ 
 [-100, -100, 1], 
 [-100, 100, 1], 
 [100, 100, 1], 
 [0, 0, 1], 
 [100, -100, 1], 
 [-100, -100, 1] 
] 

A = np.array(A)
x = A[:,0] 
y = A[:,1] 

plt.plot(x, y) 
plt.ylim([-200, 200]) 
plt.xlim([-200, 200])
# Out:
# (-200, 200)

# %%
TransformArray = np.array([
    [0.5, 0, 0],
    [0, 0.5, 0],
    [0, 0, 1]
])

# %%
B = []
for point in A:
    new_point=np.dot(TransformArray,np.transpose(point))
    B.append(new_point)
B = np.array(B).astype(int)
print(B)
# Out:
# [[-50 -50   1]
#  [-50  50   1]
#  [ 50  50   1]
#  [  0   0   1]
#  [ 50 -50   1]
#  [-50 -50   1]]

# %%
# Уменьшить объект в два раза.
x = B[:,0]
y = B[:,1]
plt.plot(x, y)

x = A[:,0]
y = A[:,1]
plt.plot(x, y, color='r')

plt.ylim([-200, 200])
plt.xlim([-200, 200])
plt.legend(['новый', 'исходный'])

# %%
# Повернуть на 130 градусов
from math import cos, sin, pi

theta = 130 * 180/pi
TransformArray_130 = np.array([
    [cos(theta), sin(theta), 0],
    [-sin(theta), cos(theta), 0],
    [0, 0, 1]
])

# %%
C = []
for point in B:
    new_point=np.dot(TransformArray_130,np.transpose(point))
    C.append(new_point)
C = np.array(C).astype(int)
print(C)
# Out:
# [[ 35  61   1]
#  [ 61 -35   1]
#  [-35 -61   1]
#  [  0   0   1]
#  [-61  35   1]
#  [ 35  61   1]]

# %%
# Повернуть на 130 градусов
plt.figure(
    figsize=(8, 8),
    )
x = C[:,0]
y = C[:,1]
plt.plot(x, y)
x = B[:,0]
y = B[:,1]
plt.plot(x, y, color='r')
plt.ylim([-100, 100])
plt.xlim([-100, 100])
plt.legend(['новый', 'исходный'])

# %%
# Отразить объект относительно прямой y=x
TransformArray_inv = np.array([
    [-1, 0, 0],
    [0, -1, 0],
    [0, 0, 1]
])

# %%
D = []
for point in C:
    new_point=np.dot(TransformArray_inv,np.transpose(point))
    D.append(new_point)
D = np.array(D).astype(int)
print(D)
# Out:
# [[-35 -61   1]
#  [-61  35   1]
#  [ 35  61   1]
#  [  0   0   1]
#  [ 61 -35   1]
#  [-35 -61   1]]

# %%
# Отразить объект относительно прямой y=x
plt.figure(
    figsize=(8, 8),
    )
x = D[:,0]
y = D[:,1]
plt.plot(x, y)
x = C[:,0]
y = C[:,1]
plt.plot(x, y, color='r')
plt.ylim([-100, 100])
plt.xlim([-100, 100])
plt.legend(['новый', 'исходный'])

# %%
# Выполнить смещение объекта и масштабирование (применить 2 матрицы трансформаций).
# Смещение на (200, 300)

# %%
TransformArray_move = np.array([
    [1, 0, 200],
    [0, 1, 300],
    [0, 0, 1]
])

# %%
E = []
for point in D:
    new_point=np.dot(TransformArray_move,np.transpose(point))
    E.append(new_point)
E = np.array(E).astype(int)
print(E)
# Out:
# [[165 239   1]
#  [139 335   1]
#  [235 361   1]
#  [200 300   1]
#  [261 265   1]
#  [165 239   1]]

# %%
plt.figure(
    figsize=(8, 8),
    )
x = E[:,0]
y = E[:,1]
plt.plot(x, y)
x = D[:,0]
y = D[:,1]
plt.plot(x, y, color='r')
plt.ylim([-100, 400])
plt.xlim([-100, 300])
plt.legend(['новый', 'исходный'])

# %%
# масштабирование на (0.5, 1,2)

# %%
TransformArray_scale = np.array([
    [0.5, 0, 0],
    [0, 1.2, 0],
    [0, 0, 1]
])

# %%
F = []
for point in E:
    new_point=np.dot(TransformArray_scale,np.transpose(point))
    F.append(new_point)
F = np.array(F).astype(int)
print(F)
# Out:
# [[ 82 286   1]
#  [ 69 402   1]
#  [117 433   1]
#  [100 360   1]
#  [130 318   1]
#  [ 82 286   1]]

# %%
plt.figure(
    figsize=(8, 8),
    )
x = F[:,0]
y = F[:,1]
plt.plot(x, y)
x = E[:,0]
y = E[:,1]
plt.plot(x, y, color='r')
plt.ylim([200, 500])
plt.xlim([50, 300])
plt.legend(['новый', 'исходный'])
